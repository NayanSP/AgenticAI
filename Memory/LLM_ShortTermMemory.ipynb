# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
llm = ChatOpenAI()

# %%
llm.invoke('My Name is NP').content
# Out:
# 'Hello NP, nice to meet you! How can I assist you today?'

# %%
llm.invoke('What is my name').content
# Out:
# "I'm sorry, but I am an AI assistant and I do not have the information about your name. Please tell me your name so I can address you correctly."

# %% [markdown]
# this show the llm calls are stateless, cant save the 2 different query asked
