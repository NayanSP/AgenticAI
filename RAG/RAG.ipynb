# %%
from __future__ import annotations

import operator
from typing import TypedDict, List, Annotated

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

from dotenv import load_dotenv
load_dotenv()
llm = ChatOpenAI()

# %%
class Task(BaseModel):
    id: int
    title: str
    brief: str = Field(..., description="What to cover")

# %%
class Plan(BaseModel):
    blog_title: str
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    # reducer: results from workers get concatenated automatically
    sections: Annotated[List[str], operator.add]
    final: str

# %%
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
def orchestrator(state: State) -> dict:

    plan = llm.with_structured_output(Plan).invoke(
        [
            SystemMessage(
                content=(
                    "Create a blog plan with 5-7 sections on the following topic."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )
    return {"plan": plan}

# %%
def fanout(state: State):
    return [Send("worker", {"task": task, "topic": state["topic"], "plan": state["plan"]})
            for task in state["plan"].tasks]

# %%
def worker(payload: dict) -> dict:

    # payload contains what we sent
    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    blog_title = plan.blog_title

    section_md = llm.invoke(
        [
            SystemMessage(content="Write one clean Markdown section."),
            HumanMessage(
                content=(
                    f"Blog: {blog_title}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Brief: {task.brief}\n\n"
                    "Return only the section content in Markdown."
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
from pathlib import Path

# %%
from pathlib import Path

def reducer(state: State) -> dict:
    
    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()

    final_md = f"# {title}\n\n{body}\n"

    # ---- save to file ----
    filename = title.lower().replace(" ", "_") + ".md"
    output_path = Path(filename)
    output_path.write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)


g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
app.invoke({"topic": "Write a blog on Self Attention", "sections": []})
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title='Understanding Self-Attention: The Heart of Modern Neural Networks', tasks=[Task(id=1, title='Introduction to Self-Attention', brief='Provide an overview of what self-attention is and why it is important in modern machine learning, particularly in natural language processing.'), Task(id=2, title='The Mechanics of Self-Attention', brief='Explain how self-attention works step-by-step, including key concepts like queries, keys, and values.'), Task(id=3, title='Self-Attention vs. Traditional Attention Mechanisms', brief='Compare self-attention with traditional attention, highlighting the differences and advantages.'), Task(id=4, title='Applications of Self-Attention', brief='Discuss real-world use cases of self-attention in models like Transformers, BERT, and GPT.'), Task(id=5, title='Benefits and Limitations', brief='Explore the strengths of self-attention and some of the challenges or limitations it faces.'), Task(id=6, title='Future Directions and Research', brief='Briefly cover ongoing research trends and potential future developments involving self-attention mechanisms.')]),
#  'sections': ['## Introduction to Self-Attention\n\nSelf-attention is a powerful mechanism in modern machine learning that enables models to weigh the importance of different parts of input data when making predictions. Unlike traditional methods that process data sequentially or focus on fixed-size contexts, self-attention dynamically captures relationships across all elements within the same input, regardless of their position.\n\nIn natural language processing (NLP), this ability is crucial because understanding language often requires grasping the dependencies between words or phrases spread throughout a sentence or document. Self-attention allows models to consider the entire context simultaneously, leading to richer, more nuanced representations of text. This mechanism is at the core of transformative architectures like the Transformer, which have revolutionized NLP tasks such as translation, summarization, and question answering by significantly improving both performance and efficiency.',
#   '## The Mechanics of Self-Attention\n\nSelf-attention is a powerful mechanism that allows neural networks to weigh the importance of different parts of an input sequence when processing it. To understand how it works, let’s break down the process step-by-step, focusing on the key components: **queries**, **keys**, and **values**.\n\n1. **Input Representation**  \n   The input to a self-attention layer is a sequence of vectors, each corresponding to a token (e.g., a word or subword) in the input. These vectors typically come from embeddings or previous network layers.\n\n2. **Generating Queries, Keys, and Values**  \n   From each input vector, the network creates three different vectors by multiplying it by three learned weight matrices:\n   - **Query (Q):** Represents the current token’s request for information.\n   - **Key (K):** Represents how well each token matches queries.\n   - **Value (V):** Contains the actual information to be aggregated.\n\n   Mathematically:\n   \\[\n   Q = XW^Q, \\quad K = XW^K, \\quad V = XW^V\n   \\]\n   where \\(X\\) is the matrix of input vectors, and \\(W^Q, W^K, W^V\\) are learned weights.\n\n3. **Computing Attention Scores**  \n   The attention score between a query and all keys is calculated by taking the dot product of the query vector with each key vector. This measures similarity or relevance:\n   \\[\n   \\text{score}(Q, K) = QK^T\n   \\]\n\n4. **Scaling the Scores**  \n   To stabilize gradients and improve training, the scores are scaled by the square root of the key dimension \\(d_k\\):\n   \\[\n   \\text{scaled score} = \\frac{QK^T}{\\sqrt{d_k}}\n   \\]\n\n5. **Applying Softmax**  \n   The scaled scores are passed through a softmax function to obtain attention weights that sum to 1. These weights determine how much focus each value should receive:\n   \\[\n   \\text{attention weights} = \\text{softmax}\\left(\\frac{QK^T}{\\sqrt{d_k}}\\right)\n   \\]\n\n6. **Weighted Sum of Values**  \n   Each value vector \\(V\\) is multiplied by its corresponding attention weight, then summed up to produce the output for the query token:\n   \\[\n   \\text{output} = \\text{attention weights} \\times V\n   \\]\n\n7. **Output and Context**  \n   This output vector now encodes information from the entire sequence, weighted by relevance to the original token. In this way, the model captures context and relationships across the input dynamically.\n\nBy repeating these steps across multiple attention heads and stacking layers, self-attention enables models like Transformers to excel at understanding complex sequences — from sentences in language to elements in other data types.',
#   '## Self-Attention vs. Traditional Attention Mechanisms\n\nAttention mechanisms have revolutionized neural networks by allowing models to focus on relevant parts of the input when making predictions. While traditional attention and self-attention share the core idea of weighting input elements based on their importance, they differ significantly in scope, structure, and effectiveness.\n\n### Traditional Attention\n\nTraditional attention mechanisms often arise in sequence-to-sequence models, such as those used in machine translation. Here, the model learns to align elements from an input sequence (e.g., words in a source sentence) to generate an output sequence (e.g., words in a target sentence). The attention is *cross-attention* by nature: it calculates weights between two different sequences — typically an encoder’s output and the decoder’s current state.\n\n**Key characteristics:**\n\n- **Cross-sequence focus:** Attention is computed between two distinct sequences.\n- **Directional:** Usually from encoder to decoder, conditioning outputs on inputs.\n- **Limited scope:** Focuses on a single relationship (input-to-output) at each step.\n\n### Self-Attention\n\nSelf-attention, on the other hand, computes attention weights within a single sequence. Each element in the sequence attends to every other element — including itself — enabling the model to capture pairwise relationships and dependencies regardless of their distance.\n\n**Key characteristics:**\n\n- **Intra-sequence focus:** Attention is computed within the same sequence.\n- **Parallelizable:** Allows processing of all tokens simultaneously, improving efficiency.\n- **Captures global context:** Each token’s representation is informed by the entire sequence.\n- **Core to Transformers:** Forms the backbone of models like BERT, GPT, and other state-of-the-art architectures.\n\n### Advantages of Self-Attention\n\n1. **Long-range dependency modeling:** Unlike traditional RNNs that struggle with long sequences, self-attention can directly link any two positions.\n2. **Efficient computation:** Self-attention enables parallel processing as it doesn’t rely on sequential data flows.\n3. **Flexible representation:** Every token obtains a context-aware embedding reflecting global sequence knowledge.\n4. **Simpler architecture:** Self-attention avoids recurrence and convolution, making implementations cleaner and more scalable.\n\n### Summary\n\nWhile traditional attention mechanisms opened the door for models to selectively focus on relevant information, self-attention expanded this concept to empower a single sequence with a holistic, interconnected understanding. This shift underpins many breakthroughs in natural language processing, computer vision, and beyond, making self-attention the heart of modern neural networks.',
#   '## Applications of Self-Attention\n\nSelf-attention has become a cornerstone technology in modern neural networks, especially in natural language processing (NLP) and beyond. Its ability to capture contextual relationships within data sequences has unlocked numerous real-world applications:\n\n- **Transformers:** Introduced in the seminal paper "Attention is All You Need," the Transformer architecture uses self-attention to effectively process sequences by weighing the importance of each token relative to others. This approach allows models to handle long-range dependencies more efficiently than traditional recurrent networks.\n\n- **BERT (Bidirectional Encoder Representations from Transformers):** BERT leverages self-attention to understand the context of words bidirectionally, considering both left and right contexts simultaneously. This capability has revolutionized tasks like question answering, sentiment analysis, and named entity recognition by providing deep semantic understanding.\n\n- **GPT (Generative Pre-trained Transformer):** GPT models use self-attention in a unidirectional manner during training to generate coherent and contextually appropriate text. This has led to breakthroughs in language generation, conversational agents, and creative writing tools.\n\nBeyond NLP, self-attention mechanisms are also proving valuable in areas such as computer vision (e.g., image classification, object detection), speech recognition, and protein folding, demonstrating their versatile and powerful role in modern AI systems.',
#   '## Benefits and Limitations\n\nSelf-attention has revolutionized the way neural networks process data, particularly in natural language processing and computer vision. Its benefits are substantial:\n\n- **Contextual Understanding:** Self-attention allows models to weigh the relevance of different parts of the input dynamically. This means the model can capture long-range dependencies and contextual relationships more effectively than traditional methods like RNNs or CNNs.\n\n- **Parallelization:** Unlike sequential models such as RNNs, self-attention mechanisms enable parallel processing of input data, resulting in significant improvements in training speed and scalability.\n\n- **Flexibility:** Self-attention is modality-agnostic—it has been successfully applied not only to text but also to images, audio, and even graph data, making it a versatile tool in the deep learning toolkit.\n\nHowever, despite its strengths, self-attention also has some limitations:\n\n- **Computational Complexity:** The self-attention operation scales quadratically with the sequence length, which can make it computationally expensive and memory-intensive for very long inputs.\n\n- **Data Efficiency:** Self-attention models typically require large amounts of training data to generalize well, which can be a limitation in domains where labeled data is scarce.\n\n- **Interpretability Challenges:** While self-attention weights offer some insight into model decisions, interpreting these weights reliably remains an ongoing research challenge, limiting transparency in some applications.\n\nOverall, understanding these benefits and limitations is crucial for effectively leveraging self-attention in modern neural network architectures.',
#   '## Future Directions and Research\n\nThe evolving landscape of self-attention mechanisms continues to inspire a wealth of research exploring new architectures, efficiency improvements, and applications. One promising direction is the development of sparse and hierarchical attention models, which aim to reduce the quadratic complexity inherent in traditional self-attention, enabling the processing of longer sequences with lower computational cost. Researchers are also investigating adaptive attention mechanisms that dynamically focus on relevant parts of the input based on context, improving interpretability and performance.\n\nIn addition, integrating self-attention with other modalities such as vision and speech is expanding its utility beyond language tasks, leading to the rise of multimodal models that can understand and generate content across text, images, and audio. Another exciting avenue is the exploration of self-attention in reinforcement learning and structured prediction, where the relationships between entities or states can be captured more effectively.\n\nFinally, theoretical analysis of self-attention’s properties — including its representational power and optimization dynamics — continues to deepen our understanding and guide the design of more robust and generalizable neural networks. As research advances, self-attention is poised to remain a foundational element that drives innovation across the field of artificial intelligence.'],
#  'final': '# Understanding Self-Attention: The Heart of Modern Neural Networks\n\n## Introduction to Self-Attention\n\nSelf-attention is a powerful mechanism in modern machine learning that enables models to weigh the importance of different parts of input data when making predictions. Unlike traditional methods that process data sequentially or focus on fixed-size contexts, self-attention dynamically captures relationships across all elements within the same input, regardless of their position.\n\nIn natural language processing (NLP), this ability is crucial because understanding language often requires grasping the dependencies between words or phrases spread throughout a sentence or document. Self-attention allows models to consider the entire context simultaneously, leading to richer, more nuanced representations of text. This mechanism is at the core of transformative architectures like the Transformer, which have revolutionized NLP tasks such as translation, summarization, and question answering by significantly improving both performance and efficiency.\n\n## The Mechanics of Self-Attention\n\nSelf-attention is a powerful mechanism that allows neural networks to weigh the importance of different parts of an input sequence when processing it. To understand how it works, let’s break down the process step-by-step, focusing on the key components: **queries**, **keys**, and **values**.\n\n1. **Input Representation**  \n   The input to a self-attention layer is a sequence of vectors, each corresponding to a token (e.g., a word or subword) in the input. These vectors typically come from embeddings or previous network layers.\n\n2. **Generating Queries, Keys, and Values**  \n   From each input vector, the network creates three different vectors by multiplying it by three learned weight matrices:\n   - **Query (Q):** Represents the current token’s request for information.\n   - **Key (K):** Represents how well each token matches queries.\n   - **Value (V):** Contains the actual information to be aggregated.\n\n   Mathematically:\n   \\[\n   Q = XW^Q, \\quad K = XW^K, \\quad V = XW^V\n   \\]\n   where \\(X\\) is the matrix of input vectors, and \\(W^Q, W^K, W^V\\) are learned weights.\n\n3. **Computing Attention Scores**  \n   The attention score between a query and all keys is calculated by taking the dot product of the query vector with each key vector. This measures similarity or relevance:\n   \\[\n   \\text{score}(Q, K) = QK^T\n   \\]\n\n4. **Scaling the Scores**  \n   To stabilize gradients and improve training, the scores are scaled by the square root of the key dimension \\(d_k\\):\n   \\[\n   \\text{scaled score} = \\frac{QK^T}{\\sqrt{d_k}}\n   \\]\n\n5. **Applying Softmax**  \n   The scaled scores are passed through a softmax function to obtain attention weights that sum to 1. These weights determine how much focus each value should receive:\n   \\[\n   \\text{attention weights} = \\text{softmax}\\left(\\frac{QK^T}{\\sqrt{d_k}}\\right)\n   \\]\n\n6. **Weighted Sum of Values**  \n   Each value vector \\(V\\) is multiplied by its corresponding attention weight, then summed up to produce the output for the query token:\n   \\[\n   \\text{output} = \\text{attention weights} \\times V\n   \\]\n\n7. **Output and Context**  \n   This output vector now encodes information from the entire sequence, weighted by relevance to the original token. In this way, the model captures context and relationships across the input dynamically.\n\nBy repeating these steps across multiple attention heads and stacking layers, self-attention enables models like Transformers to excel at understanding complex sequences — from sentences in language to elements in other data types.\n\n## Self-Attention vs. Traditional Attention Mechanisms\n\nAttention mechanisms have revolutionized neural networks by allowing models to focus on relevant parts of the input when making predictions. While traditional attention and self-attention share the core idea of we ...

# %%
app.invoke({"topic": "Write a blog on Transformer: Encoder Decoder", "sections": []})
# Out:
# {'topic': 'Write a blog on Transformer: Encoder Decoder',
#  'plan': Plan(blog_title='Understanding Transformer Architecture: Encoder-Decoder Explained', tasks=[Task(id=1, title='Introduction to Transformer Models', brief='Provide an overview of the Transformer architecture, its significance in deep learning, and its impact on natural language processing tasks.'), Task(id=2, title='Understanding the Encoder Component', brief='Explain the structure and functionality of the encoder part of the Transformer, including self-attention and feed-forward layers.'), Task(id=3, title='Understanding the Decoder Component', brief="Describe the decoder's structure, masked self-attention, cross-attention mechanisms, and how it generates outputs step-by-step."), Task(id=4, title='Encoder-Decoder Interaction', brief='Detail how the encoder and decoder work together, focusing on how encoder outputs inform the decoder during sequence generation.'), Task(id=5, title='Applications of Transformer Encoder-Decoder Models', brief='Highlight real-world applications such as machine translation, text summarization, and other sequence-to-sequence tasks.'), Task(id=6, title='Advantages and Limitations of Transformer Encoder-Decoders', brief='Discuss the benefits of this architecture along with challenges and areas for future research.')]),
#  'sections': ['## Introduction to Transformer Models\n\nThe Transformer architecture, introduced by Vaswani et al. in 2017, has revolutionized the field of deep learning, particularly in natural language processing (NLP). Unlike traditional sequence models such as recurrent neural networks (RNNs) and long short-term memory networks (LSTMs), Transformers rely entirely on self-attention mechanisms to process input data. This approach allows Transformers to capture long-range dependencies more efficiently and parallelize training, leading to significant improvements in performance and scalability.\n\nTransformers have become the foundation for many state-of-the-art NLP models, powering applications like machine translation, text summarization, and question answering. Their ability to handle vast amounts of textual data with remarkable accuracy and speed has made them indispensable in modern AI, enabling breakthroughs that were previously unattainable with earlier architectures. Understanding the Transformer model is key to grasping the advancements in AI-driven language technology today.',
#   '## Understanding the Encoder Component\n\nThe encoder is a fundamental part of the Transformer architecture, designed to process and encode the input data into a rich, contextual representation that the decoder can later utilize to generate meaningful output. It consists primarily of a stack of identical layers, each composed of two main subcomponents: self-attention mechanisms and position-wise feed-forward networks.\n\n### Self-Attention Mechanism\n\nAt the heart of the encoder lies the self-attention layer, which allows the model to weigh the importance of different words in the input sequence relative to each other. Unlike previous sequence models that processed data sequentially, self-attention enables the encoder to consider all positions in the input simultaneously. For each token, the mechanism computes attention scores with every other token in the sequence, effectively capturing dependencies regardless of distance. This results in a set of contextualized embeddings where the meaning of each word is informed by its surrounding words, enhancing the model’s understanding of the input.\n\n### Position-Wise Feed-Forward Networks\n\nFollowing the self-attention layer, each encoder layer includes a position-wise feed-forward network (FFN). This component applies two linear transformations with a ReLU activation in between, independently and identically to each position. The FFN serves to further process and transform the representations generated by the self-attention layer, enabling the model to capture more complex patterns and interactions within the data.\n\n### Additional Components\n\nTo maintain stability and improve learning, each sub-layer is wrapped with residual connections and layer normalization. Additionally, since the Transformer does not have any inherent notion of sequence order due to the parallel processing of tokens, positional encodings are added to the input embeddings at the very start. These encodings inject information about the position of each token, allowing the encoder to maintain the order of the input sequence.\n\nTogether, these elements enable the encoder to generate robust and contextually rich representations of the input data, laying the groundwork for effective sequence-to-sequence modeling in various natural language processing tasks.',
#   '## Understanding the Decoder Component\n\nThe decoder is a crucial part of the Transformer architecture, designed to generate output sequences by attending to both previously generated tokens and the encoded input representations. Its structure closely mirrors that of the encoder but includes additional mechanisms tailored for sequence generation.\n\n### Structure of the Decoder\n\nEach decoder layer consists of three main sub-layers:\n\n1. **Masked Self-Attention:** Allows the decoder to attend to earlier positions in the output sequence while preventing access to future tokens.\n2. **Cross-Attention (Encoder-Decoder Attention):** Enables the decoder to focus on relevant encoded input features.\n3. **Position-wise Feed-Forward Network:** Applies non-linearity and transformation to the attended information.\n\nLayer normalization and residual connections surround each sub-layer to facilitate stable training and gradient flow.\n\n### Masked Self-Attention\n\nUnlike the encoder’s self-attention, the decoder employs **masked self-attention** to maintain the autoregressive property during sequence generation. This means at each position, the decoder can only attend to tokens up to that position, ensuring the model does not peek into the future tokens it hasn’t generated yet.\n\nThis masking is implemented by applying a triangular attention mask that blocks any connection to subsequent positions. As a result, when generating the next token, the decoder conditions only on the past outputs.\n\n### Cross-Attention Mechanism\n\nAfter attending to its own previously generated tokens, the decoder uses **cross-attention** to focus on relevant parts of the encoded input sequence. This attention layer takes the encoder’s output as keys and values, and the decoder’s masked self-attention output as queries.\n\nBy doing so, the decoder effectively incorporates contextual information from the input sequence, enabling it to generate coherent and contextually appropriate output tokens.\n\n### Step-by-Step Output Generation\n\nThe decoding process unfolds iteratively:\n\n1. **Initialization:** The decoder starts with a special start-of-sequence token.\n2. **Masked Self-Attention:** For each step, it attends to all previously generated tokens using masked self-attention.\n3. **Cross-Attention:** It attends to the encoder output to gather context relevant to the input.\n4. **Feed-Forward Processing:** The attended information passes through position-wise feed-forward layers.\n5. **Output Prediction:** The decoder outputs a probability distribution over the vocabulary for the next token.\n6. **Token Selection:** The next token is selected (via sampling or argmax) and appended to the generated sequence.\n7. **Repeat:** Steps 2 to 6 iterate until an end-of-sequence token is produced or a maximum length is reached.\n\nThis auto-regressive decoding strategy, combined with the powerful attention mechanisms, enables the Transformer decoder to generate highly accurate and context-sensitive sequences across a variety of natural language processing tasks.',
#   "## Encoder-Decoder Interaction\n\nThe Transformer architecture's strength lies in the seamless interaction between its encoder and decoder components, which enables efficient and accurate sequence generation. \n\nThe **encoder** processes the input sequence by passing it through multiple layers of self-attention and feed-forward networks. This results in a rich set of contextualized representations, capturing relationships and dependencies within the input data. These representations, often called *encoder outputs*, encode how each part of the input relates to every other part, effectively summarizing the input’s meaning.\n\nDuring sequence generation, the **decoder** leverages these encoder outputs to produce the desired output sequence step-by-step. At each decoding step, the decoder performs its own self-attention over previously generated tokens to maintain coherence. Crucially, it also uses *encoder-decoder attention* mechanisms, where it attends to the encoder outputs. This allows the decoder to selectively focus on relevant parts of the input sequence to inform its next token prediction.\n\nBy integrating the context from the encoder, the decoder gains access to a comprehensive understanding of the input, enabling it to generate output sequences that are contextually aligned and accurate. This tight coupling is what makes the Transformer particularly effective in tasks like machine translation, text summarization, and other sequence-to-sequence problems.",
#   '## Applications of Transformer Encoder-Decoder Models\n\nTransformer encoder-decoder architectures have revolutionized the way we handle sequence-to-sequence tasks across various domains. Their ability to model complex dependencies and generate high-quality outputs has paved the way for numerous real-world applications, including:\n\n- **Machine Translation:** Transformers have become the backbone of modern machine translation systems, enabling more accurate and fluent translation between languages. Unlike traditional models, they can capture long-range context efficiently, resulting in translations that are both grammatically correct and contextually relevant.\n\n- **Text Summarization:** Encoder-decoder models excel at generating concise summaries from lengthy documents. By encoding the input text and decoding a shorter version, these models help users quickly grasp the main ideas without reading the entire content.\n\n- **Question Answering:** In tasks where the input is a passage and a question, these models can generate precise answers by understanding the context and relevant information, improving the responsiveness and accuracy of virtual assistants and chatbots.\n\n- **Code Generation and Refinement:** Transformers can translate natural language descriptions into code snippets or refine existing code, aiding developers by automating parts of the programming process.\n\n- **Speech Recognition and Synthesis:** Through sequence-to-sequence mapping, encoder-decoder models contribute to converting spoken language into text and vice versa, enhancing voice-based applications and accessibility tools.\n\nOverall, the transformer encoder-decoder framework provides a flexible and powerful solution for any task that involves converting one sequence into another, making it a cornerstone technology in natural language processing and beyond.',
#   '## Advantages and Limitations of Transformer Encoder-Decoders\n\nTransformer encoder-decoder architectures have revolutionized the field of natural language processing and beyond, bringing significant benefits but also posing unique challenges.\n\n### Advantages\n\n- **Parallelization and Efficiency:** Unlike recurrent models, transformers process input data in parallel, drastically reducing training time and enabling efficient handling of large datasets.\n- **Long-Range Dependency Modeling:** The self-attention mechanism allows the model to capture dependencies across long sequences, improving context understanding in tasks like translation and summarization.\n- **Flexibility Across Tasks:** Encoder-decoder frameworks can be adapted to various applications including machine translation, text generation, and even vision tasks, demonstrating versatile utility.\n- **Improved Performance:** These models have set new state-of-the-art benchmarks in numerous NLP tasks by effectively capturing semantic and syntactic information.\n\n### Limitations\n\n- **Computationally Intensive:** Despite parallelization, transformers require substantial computational resources and memory, especially with increasing model size and sequence length.\n- **Data Hunger:** Large amounts of high-quality labeled data are often necessary to train effective models, which can be a barrier for low-resource languages or specialized domains.\n- **Interpretability Issues:** The complexity of the attention mechanisms makes it challenging to interpret exactly how and why specific predictions are made.\n- **Fixed-Length Input Constraints:** Although more flexible than previous models, transformers still face difficulties processing very long sequences due to quadratic scaling of attention computation.\n\n### Future Research Directions\n\n- **Efficient Attention Mechanisms:** Developing sparse or approximate attention methods to reduce computational costs without sacrificing accuracy.\n- **Low-Resource Adaptation:** Techniques like transfer learning, few-shot learning, and data augmentation for making transformer models accessible to low-data scenarios.\n- **Explainability Enhancements:** Improving transparency through better visualization and analysis of attention patterns.\n- **Multimodal Integration:** Extending encoder-decoder frameworks to seamlessly combine text, vision, and audio data for richer understanding and generation.\n\nBy addressing these challenges, future iterations of transformer encoder-decoder models promise to become even more powerful, efficient, and broadly applicable, driving forward the capabilities of artificial intelligence.'],
#  'final': "# Understanding Transformer Architecture: Encoder-Decoder Explained\n\n## Introduction to Transformer Models\n\nThe Transformer architecture, introduced by Vaswani et al. in 2017, has revolutionized the field of deep learning, particularly in natural language processing (NLP). Unlike traditional sequence models such as recurrent neural networks (RNNs) and long short-term memory networks (LSTMs), Transformers rely entirely on self-attention mechanisms to process input data. This approach allows Transformers to capture long-range dependencies more efficiently and parallelize training, leading to significant improvements in performance and scalability.\n\nTransformers have become the foundation for many state-of-the-art NLP models, powering applications like machine translation, text summarization, and question answering. Their ability to handle vast amounts of textual data with remarkable accuracy and speed has made them indispensable in modern AI, enabling breakthroughs that were previously unattainable with earlier architectures. Understanding the Transformer model is key to grasping the advancements in AI-driven language technology today.\n\n## Understanding the Encoder Component\n\nThe encoder is a fundamental part of the Transformer architecture, designed to process and encode the input data into a rich, contextual representation that the decoder can later utilize to generate meaningful output. It consists primarily of a stack of identical layers, each composed of two main subcomponents: self-attention mechanisms and position-wise feed-forward networks.\n\n### Self-Attention Mechanism\n\nAt the heart of the encoder lies the self-attention layer, which allows the model to weigh the importance of different words in the input sequence relative to each other. Unlike previous sequence models that processed data sequentially, self-attention enables the encoder to consider all positions in the input simultaneously. For each token, the mechanism computes attention scores with every other token in the sequence, effectively capturing dependencies regardless of distance. This results in a set of contextualized embeddings where the meaning of each word is informed by its surrounding words, enhancing the model’s understanding of the input.\n\n### Position-Wise Feed-Forward Networks\n\nFollowing the self-attention layer, each encoder layer includes a position-wise feed-forward network (FFN). This component applies two linear transformations with a ReLU activation in between, independently and identically to each position. The FFN serves to further process and transform the representations generated by the self-attention layer, enabling the model to capture more complex patterns and interactions within the data.\n\n### Additional Components\n\nTo maintain stability and improve learning, each sub-layer is wrapped with residual connections and layer normalization. Additionally, since the Transformer does not have any inherent notion of sequence order due to the parallel processing of tokens, positional encodings are added to the input embeddings at the very start. These encodings inject information about the position of each token, allowing the encoder to maintain the order of the input sequence.\n\nTogether, these elements enable the encoder to generate robust and contextually rich representations of the input data, laying the groundwork for effective sequence-to-sequence modeling in various natural language processing tasks.\n\n## Understanding the Decoder Component\n\nThe decoder is a crucial part of the Transformer architecture, designed to generate output sequences by attending to both previously generated tokens and the encoded input representations. Its structure closely mirrors that of the encoder but includes additional mechanisms tailored for sequence generation.\n\n### Structure of the Decoder\n\nEach decoder layer consists of three main sub-layers:\n\n1. **Masked Self-Attention:** Allows the decoder to attend to earli ...
